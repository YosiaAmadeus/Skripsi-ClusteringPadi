# %%
#Import Library
import pandas as pd
import numpy as np
import skfuzzy as fuzz
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
#Membaca dan Menampilkan Dataset
#Menjadikan Kolom 'Lokasi' Sebagai Index
df = pd.read_excel('AllProvince 2.0.xlsx', index_col = 'Lokasi')
df
# Out:
#                                2010 (Luas Panen)  2010 (Produksi)
# Lokasi
# Aceh                                      352281       1582391.00  \
# Sumatera Utara                            757674       3582302.00
# Sumatera Barat                            460497       2211248.00
# Riau                                      156088        574864.00
# Jambi                                     153897        628828.00
# Sumatera Selatan                          769478       3272449.00
# Bengkulu                                  133629        516868.00
# Lampung                                   590608       2756517.00
# Kepulauan Bangka Belitung                   8180         22259.00
# Kepulauan Riau                               396          1246.00
# Daerah Khusus Ibukota Jakarta               1002         11985.86
# Jawa Barat                               2037657      11737072.00
# Jawa Tengah                              1851208      10110830.00
# Daerah Istimewa Yogyakarta                147058        823887.00
# Jawa Timur                               1963883      11673772.00
# Banten                                    406411       2048047.00
# Bali                                      152190        869160.00
# Nusa Tenggara Barat                       374284       1774499.00
# Nusa Tenggara Timur                       174674        555494.00
# Kalimantan Barat                          428461       1343890.00
# Kalimantan Tengah                         247577        650416.00
# Kalimantan Selatan                        471166       1842090.00
# Kalimantan Timur                          149797        588109.00
# Kalimantan Utara                           41115        112102.00
# Sulawesi Utara                            119771        584031.00
# Sulawesi Tengah                           208085        955089.00
# Sulawesi Selatan                          886354       4372441.00
# Sulawesi Tenggara                         107751        454644.00
# Gorontalo                                  46326        245786.00
# Sulawesi Barat                             75473        362900.00
# Maluku                                     20233        102761.00
# Maluku Utara                               16071         55401.00
# Papua Barat                                 9464         34255.00
# Papua                                      26626        102621.00
#
#                                2010 (Produktivitas)  2011 (Luas Panen)
# Lokasi
# Aceh                                          44.92             380686  \
# Sumatera Utara                                47.47             757547
# Sumatera Barat                                48.49             461709
# Riau                                          36.83             145242
# Jambi                                         40.86             157441
# Sumatera Selatan                              42.53             784820
# Bengkulu                                      38.68             127936
# Lampung                                       47.54             606973
# Kepulauan Bangka Belitung                     27.21               5299
# Kepulauan Riau                                31.60                399
# Daerah Khusus Ibukota Jakarta                 55.40               1002
# Jawa Barat                                    57.60            1964426
# Jawa Tengah                                   56.13            1724246
# Daerah Istimewa Yogyakarta                    56.02             150827
# Jawa Timur                                    59.29            1926796
# Banten                                        50.39             397021
# Bali                                          57.11             152585
# Nusa Tenggara Barat                           47.41             418062
# Nusa Tenggara Timur                           31.80             195201
# Kalimantan Barat                              31.37             444353
# Kalimantan Tengah                             26.27             214161
# Kalimantan Selatan                            39.10             489134
# Kalimantan Timur                              39.25             140215
# Kalimantan Utara                              34.72              41115
# Sulawesi Utara                                48.76             122108
# Sulawesi Tengah                               45.88             221846
# Sulawesi Selatan                              49.44             889232
# Sulawesi Tenggara                             42.19             118916
# Gorontalo                                     55.20              52811
# Sulawesi Barat                                47.80              76347
# Maluku                                        41.08              42481
# Maluku Utara                                  36.60              16783
# Papua Barat                                   36.19               8283
# Papua                                         38.45              29145
#
#                                2011 (Produksi)  2011 (Produktivitas)
# Lokasi
# Aceh                                1772961.00                 46.57  \
# Sumatera Utara                      3607405.00                 47.62
# Sumatera Barat                      2279602.00                 49.37
# Riau                                 535788.00                 36.89
# Jambi                                625868.00                 41.07
# Sumatera Selatan                    3384668.00                 43.13
# Bengkulu                             502550.00                 39.28
# Lampung                             2940794.00                 48.45
# Kepulauan Bangka Belitung             15210.00                 28.71
# Kepulauan Riau                         1259.63                 31.60
# Daerah Khusus Ibukota Jakarta         11985.86                 55.23
# Jawa Barat                         11643871.00                 59.22
# Jawa Tengah                         9391958.00                 54.47
# Daerah Istimewa Yogyakarta           840934.00                 55.89
# Jawa Timur                         10476543.00                 54.89
# Banten                              1949715.00                 49.11
# Bali                                 858317.00                 56.25
# Nusa Tenggara Barat                 2067137.00                 49.45
# Nusa Tenggara Timur                  591371.00                 30.30
# Kalimantan Barat                    1372989.00                 30.90
# Kalimantan Tengah                    610236.00                 28.49
# Kalimantan Selatan                  2039114.00                 41.67
# Kalimantan Timur                     552615.00                 39.41
# Kalimantan Utara                     112102.00                 34.72
# Sulawesi Utara                       596237.00                 48.83
# Sulawesi Tengah                     1041789.00                 46.96
# Sulawesi Selatan                    4511704.00                 50.74
# Sulawesi Tenggara                    485052.00                 41.34
# Gorontalo                            245786.00                 51.87
# Sulawesi Barat                       365683.00                 47.90
# Maluku                               102761.00                 41.21
# Maluku Utara                          61453.00                 36.60
# Papua Barat                           29305.00                 35.38
# Papua                                115392.00                 39.45
#
#                                2012 (Luas Panen)  2012 (Produksi)
# Lokasi
# Aceh                                      387803       1788738.00  \
# Sumatera Utara                            765099       3715084.00
# Sumatera Barat                            476422       2368390.00
# Riau                                      144008        512152.00
# Jambi                                     149369        625166.00
# Sumatera Selatan                          769725       3295246.00
# Bengkulu                                  144448        581912.00
# Lampung                                   641876       3101455.00
# Kepulauan Bangka Belitung                   7995         22393.00
# Kepulauan Riau                               377          1323.30
# Daerah Khusus Ibukota Jakarta               1002         11985.86
# Jawa Barat                               1918799      11271861.00
# Jawa Tengah                              1773558      10232933.00
# Daerah Istimewa Yogyakarta                152912        946224.00
# Jawa Timur                               1975719      11261081.00
# Banten                                    362636       1865896.00
# Bali                                      148347        864202.00
# Nusa Tenggara Barat                       425448       2114231.00
# Nusa Tenggara Timur                       200094        698566.00
# Kalimantan Barat                          427798       1300101.00
# Kalimantan Tengah                         251787        815313.00
# Kalimantan Selatan                        495632       2086220.00
# Kalimantan Timur                          142573        561958.00
# Kalimantan Utara                           41115        112102.00
# Sulawesi Utara                            126841        614888.00
# Sulawesi Tengah                           229080       1024315.00
# Sulawesi Selatan                          981390       5003008.00
# Sulawesi Tenggara                         124511        516293.00
# Gorontalo                                  51193        245786.00
# Sulawesi Barat                             83796        412337.00
# Maluku                                     19639        102761.00
# Maluku Utara                               17794         65686.00
# Papua Barat                                 7750         30242.00
# Papua                                      37205        138034.00
#
#                                2012 (Produktivitas)  2013 (Luas Panen)  ...
# Lokasi                                                                  ...
# Aceh                                          46.12             419183  ...  \
# Sumatera Utara                                48.56             742968  ...
# Sumatera Barat                                49.71             487820  ...
# Riau                                          35.56             118518  ...
# Jambi                                         41.85             153243  ...
# Sumatera Selatan                              42.81             800036  ...
# Bengkulu                                      40.29             147680  ...
# Lampung                                       48.32             638090  ...
# Kepulauan Bangka Belitung                     28.01              10227  ...
# Kepulauan Riau                                34.63                379  ...
# Daerah Khusus Ibukota Jakarta                 58.22               1002  ...
# Jawa Barat                                    58.74            2029891  ...
# Jawa Tengah                                   57.70            1845447  ...
# Daerah Istimewa Yogyakarta                    61.88             159266  ...
# Jawa Timur                                    61.74            2037021  ...
# Banten                                        51.45             393704  ...
# Bali                                          58.09             149832  ...
# Nusa Tenggara Barat                           49.69             438057  ...
# Nusa Tenggara Timur                           34.91             222469  ...
# Kalimantan Barat                              30.39             444070  ...
# Kalimantan Tengah                             30.01             247473  ...
# Kalimantan Selatan                            42.05             479721  ...
# Kalimantan Timur                              39.42             138838  ...
# Kalimantan Utara                              34.72              41115  ...
# Sulawesi Utara                                48.46             127413  ...
# Sulawesi Tengah                               44.71             224326  ...
# Sulawesi Selatan                              50.98             983107  ...
# Sulawesi Tenggara                             41.47             132945  ...
# Gorontalo                                     48.01              56894  ...
# Sulawesi Barat                                49.21              91195  ...
# Maluku                                        41.13              24399  ...
# Maluku Utara                                  36.91              19281  ...
# Papua Barat                                   39.03               7523  ...
# Papua                                         37.16              40814  ...
#
#                                2020 (Produktivitas)  2021 (Luas Panen)
# Lokasi
# Aceh                                          55.28          297058.38  \
# Sumatera Utara                                52.51          385405.00
# Sumatera Barat                                46.92          272391.95
# Riau                                          37.64           53062.35
# Jambi                                         45.58           64412.26
# Sumatera Selatan                              49.75          496241.65
# Bengkulu                                      45.66           55704.69
# Lampung                                       48.62          489573.23
# Kepulauan Bangka Belitung                     32.13           18278.27
# Kepulauan Riau                                28.56             270.16
# Daerah Khusus Ibukota Jakarta                 49.69             559.97
# Jawa Barat                                    56.82         1604109.00
# Jawa Tengah                                   56.93         1696712.36
# Daerah Istimewa Yogyakarta                    47.35          107506.16
# Jawa Timur                                    56.68         1747481.20
# Banten                                        50.88          318248.46
# Bali                                          58.49          105201.31
# Nusa Tenggara Barat                           48.17          276211.88
# Nusa Tenggara Timur                           39.90          174900.07
# Kalimantan Barat                              30.33          223166.00
# Kalimantan Tengah                             31.96          125870.05
# Kalimantan Selatan                            39.69          254263.59
# Kalimantan Timur                              35.67           66269.46
# Kalimantan Utara                              33.97            8880.83
# Sulawesi Utara                                40.25           59182.00
# Sulawesi Tengah                               44.49          182186.62
# Sulawesi Selatan                              48.23          985158.23
# Sulawesi Tenggara                             39.85          127517.29
# Gorontalo                                     46.75           48713.50
# Sulawesi Barat                                53.23           59763.18
# Maluku                                        38.53           28319.75
# Maluku Utara                                  42.11            7782.00
# Papua Barat                                   32.20            6414.94
# Papua                                         31.48           64984.90
#
#                                2021 (Produksi)  2021 (Produktivitas)
# Lokasi
# Aceh                                1634639.60                 55.03  \
# Sumatera Utara                      2004142.51                 52.00
# Sumatera Barat                      1317209.38                 48.36
# Riau                                 217458.87                 40.98
# Jambi                                298149.25                 46.29
# Sumatera Selatan                    2552443.19                 51.44
# Bengkulu                             271117.19                 48.67
# Lampung                             2485452.78                 50.77
# Kepulauan Bangka Belitung             70496.25                 38.57
# Kepulauan Riau                          855.01                 31.65
# Daerah Khusus Ibukota Jakarta          3249.47                 58.03
# Jawa Barat                          9113574.00                 56.81
# Jawa Tengah                         9618656.81                 56.69
# Daerah Istimewa Yogyakarta           556531.03                 51.77
# Jawa Timur                          9789587.67                 56.02
# Banten                              1603247.00                 51.21
# Bali                                 618910.81                 58.83
# Nusa Tenggara Barat                 1419559.84                 51.39
# Nusa Tenggara Timur                  731877.74                 41.85
# Kalimantan Barat                     711897.00                 31.90
# Kalimantan Tengah                    381189.55                 30.28
# Kalimantan Selatan                   381143.20                 39.97
# Kalimantan Timur                     244677.96                 36.92
# Kalimantan Utara                      29967.31                 33.74
# Sulawesi Utara                       228995.95                 38.69
# Sulawesi Tengah                      867012.77                 47.59
# Sulawesi Selatan                    5090637.23                 51.67
# Sulawesi Tenggara                    530029.08                 41.57
# Gorontalo                            234392.86                 48.12
# Sulawesi Barat                       311072.46                 52.05
# Maluku                               116803.67                 41.24
# Maluku Utara                          28052.00                 36.05
# Papua Barat                           26926.93                 41.98
# Papua                                286279.80                 44.05
#
#                                2022 (Luas Panen)  2022 (Produksi)
# Lokasi
# Aceh                                   271750.16       1509456.46  \
# Sumatera Utara                         411462.10       2088583.81
# Sumatera Barat                         271883.11       1373532.19
# Riau                                    51054.04        213557.23
# Jambi                                   60539.59        277743.83
# Sumatera Selatan                       513378.20       2775069.26
# Bengkulu                                57151.84        281610.09
# Lampung                                518256.06       2688159.74
# Kepulauan Bangka Belitung               15107.80         61425.07
# Kepulauan Riau                            179.48           506.91
# Daerah Khusus Ibukota Jakarta             477.25          2337.77
# Jawa Barat                            1662403.00       9488934.00
# Jawa Tengah                           1688669.65       9356445.49
# Daerah Istimewa Yogyakarta             110927.24        561699.53
# Jawa Timur                            1693210.70       9526515.67
# Banten                                 337240.74       1788582.60
# Bali                                   112320.62        680601.60
# Nusa Tenggara Barat                    270092.88       1452945.47
# Nusa Tenggara Timur                    183091.99        756049.91
# Kalimantan Barat                       241478.00        731225.00
# Kalimantan Tengah                      108226.75        343918.75
# Kalimantan Selatan                     214908.91        343893.82
# Kalimantan Timur                        64970.01        239425.34
# Kalimantan Utara                         8604.19         30533.59
# Sulawesi Utara                          58195.00        253478.94
# Sulawesi Tengah                        168993.18        744408.70
# Sulawesi Selatan                      1038084.29       5360169.37
# Sulawesi Tenggara                      117989.00        478958.03
# Gorontalo                               46823.47        240134.53
# Sulawesi Barat                          69323.95        353513.29
# Maluku                                  23987.82         92601.06
# Maluku Utara                             6416.00         24486.00
# Papua Barat                              5460.59         23963.92
# Papua                                   49741.91        193943.47
#
#                                2022 (Produktivitas)  2023 (Luas Panen)
# Lokasi
# Aceh                                          55.55          254287.38  \
# Sumatera Utara                                50.76          406109.49
# Sumatera Barat                                50.52          300564.77
# Riau                                          41.83           51914.14
# Jambi                                         45.88           61236.64
# Sumatera Selatan                              54.06          504143.03
# Bengkulu                                      49.27           57877.18
# Lampung                                       51.87          530108.09
# Kepulauan Bangka Belitung                     40.66           15284.56
# Kepulauan Riau                                28.24             115.27
# Daerah Khusus Ibukota Jakarta                 48.98             542.93
# Jawa Barat                                    57.08         1583657.00
# Jawa Tengah                                   55.41         1642761.23
# Daerah Istimewa Yogyakarta                    50.64          105693.66
# Jawa Timur                                    56.26         1698083.31
# Banten                                        53.04          311199.73
# Bali                                          60.59          108514.06
# Nusa Tenggara Barat                           53.79          287512.14
# Nusa Tenggara Timur                           41.29          184698.89
# Kalimantan Barat                              30.28          224068.00
# Kalimantan Tengah                             31.78          101580.30
# Kalimantan Selatan                            38.13          214283.82
# Kalimantan Timur                              36.85          101642.09
# Kalimantan Utara                              35.49            6499.92
# Sulawesi Utara                                43.56           54562.95
# Sulawesi Tengah                               44.05          177699.03
# Sulawesi Selatan                              51.64          967790.21
# Sulawesi Tenggara                             40.59          113930.26
# Gorontalo                                     51.29           49610.47
# Sulawesi Barat                                50.99           58606.67
# Maluku                                        38.60           22636.68
# Maluku Utara                                  38.16            7708.00
# Papua Barat                                   43.89            5006.27
# Papua                                         38.99             840.18
#
#                                2023 (Produksi)  2023 (Produktivitas)
# Lokasi
# Aceh                                1404234.82                 55.22
# Sumatera Utara                      2090475.17                 51.40
# Sumatera Barat                      1482468.79                 49.32
# Riau                                 205972.55                 39.68
# Jambi                                275941.45                 45.06
# Sumatera Selatan                    2832773.92                 56.19
# Bengkulu                             286684.43                 49.53
# Lampung                             2757898.19                 52.03
# Kepulauan Bangka Belitung             66468.89                 43.49
# Kepulauan Riau                          324.01                 28.11
# Daerah Khusus Ibukota Jakarta          2674.28                 49.26
# Jawa Barat                          9140040.00                 57.71
# Jawa Tengah                         9084107.53                 55.30
# Daerah Istimewa Yogyakarta           534113.69                 50.53
# Jawa Timur                          9710661.33                 57.19
# Banten                              1686483.29                 54.19
# Bali                                 655897.71                 62.07
# Nusa Tenggara Barat                 1538536.92                 53.51
# Nusa Tenggara Timur                  766810.46                 41.52
# Kalimantan Barat                     700290.00                 31.25
# Kalimantan Tengah                    330781.05                 32.56
# Kalimantan Selatan                   875545.73                 40.86
# Kalimantan Timur                     226972.07                 39.76
# Kalimantan Utara                      23602.11                 36.31
# Sulawesi Utara                       238193.41                 43.65
# Sulawesi Tengah                      821367.41                 46.22
# Sulawesi Selatan                    4876386.11                 50.39
# Sulawesi Tenggara                    479407.25                 42.08
# Gorontalo                            251431.76                 50.68
# Sulawesi Barat                       291458.59                 49.73
# Maluku                                79958.34                 35.32
# Maluku Utara                          26662.00                 34.59
# Papua Barat                           22566.81                 45.08
# Papua                                196723.13                 41.34
#
# [34 rows x 42 columns]

# %%
#Memeriksa Missing Values
null_values = df.isnull()
print(null_values)
df.describe()
# Out:
#                                2010 (Luas Panen)  2010 (Produksi)
# Lokasi
# Aceh                                       False            False  \
# Sumatera Utara                             False            False
# Sumatera Barat                             False            False
# Riau                                       False            False
# Jambi                                      False            False
# Sumatera Selatan                           False            False
# Bengkulu                                   False            False
# Lampung                                    False            False
# Kepulauan Bangka Belitung                  False            False
# Kepulauan Riau                             False            False
# Daerah Khusus Ibukota Jakarta              False            False
# Jawa Barat                                 False            False
# Jawa Tengah                                False            False
# Daerah Istimewa Yogyakarta                 False            False
# Jawa Timur                                 False            False
# Banten                                     False            False
# Bali                                       False            False
# Nusa Tenggara Barat                        False            False
# Nusa Tenggara Timur                        False            False
# Kalimantan Barat                           False            False
# Kalimantan Tengah                          False            False
# Kalimantan Selatan                         False            False
# Kalimantan Timur                           False            False
# Kalimantan Utara                           False            False
# Sulawesi Utara                             False            False
# Sulawesi Tengah                            False            False
# Sulawesi Selatan                           False            False
# Sulawesi Tenggara                          False            False
# Gorontalo                                  False            False
# Sulawesi Barat                             False            False
# Maluku                                     False            False
# Maluku Utara                               False            False
# Papua Barat                                False            False
# Papua                                      False            False
#
#                                2010 (Produktivitas)  2011 (Luas Panen)
# Lokasi
# Aceh                                          False              False  \
# Sumatera Utara                                False              False
# Sumatera Barat                                False              False
# Riau                                          False              False
# Jambi                                         False              False
# Sumatera Selatan                              False              False
# Bengkulu                                      False              False
# Lampung                                       False              False
# Kepulauan Bangka Belitung                     False              False
# Kepulauan Riau                                False              False
# Daerah Khusus Ibukota Jakarta                 False              False
# Jawa Barat                                    False              False
# Jawa Tengah                                   False              False
# Daerah Istimewa Yogyakarta                    False              False
# Jawa Timur                                    False              False
# Banten                                        False              False
# Bali                                          False              False
# Nusa Tenggara Barat                           False              False
# Nusa Tenggara Timur                           False              False
# Kalimantan Barat                              False              False
# Kalimantan Tengah                             False              False
# Kalimantan Selatan                            False              False
# Kalimantan Timur                              False              False
# Kalimantan Utara                              False              False
# Sulawesi Utara                                False              False
# Sulawesi Tengah                               False              False
# Sulawesi Selatan                              False              False
# Sulawesi Tenggara                             False              False
# Gorontalo                                     False              False
# Sulawesi Barat                                False              False
# Maluku                                        False              False
# Maluku Utara                                  False              False
# Papua Barat                                   False              False
# Papua                                         False              False
#
#                                2011 (Produksi)  2011 (Produktivitas)
# Lokasi
# Aceh                                     False                 False  \
# Sumatera Utara                           False                 False
# Sumatera Barat                           False                 False
# Riau                                     False                 False
# Jambi                                    False                 False
# Sumatera Selatan                         False                 False
# Bengkulu                                 False                 False
# Lampung                                  False                 False
# Kepulauan Bangka Belitung                False                 False
# Kepulauan Riau                           False                 False
# Daerah Khusus Ibukota Jakarta            False                 False
# Jawa Barat                               False                 False
# Jawa Tengah                              False                 False
# Daerah Istimewa Yogyakarta               False                 False
# Jawa Timur                               False                 False
# Banten                                   False                 False
# Bali                                     False                 False
# Nusa Tenggara Barat                      False                 False
# Nusa Tenggara Timur                      False                 False
# Kalimantan Barat                         False                 False
# Kalimantan Tengah                        False                 False
# Kalimantan Selatan                       False                 False
# Kalimantan Timur                         False                 False
# Kalimantan Utara                         False                 False
# Sulawesi Utara                           False                 False
# Sulawesi Tengah                          False                 False
# Sulawesi Selatan                         False                 False
# Sulawesi Tenggara                        False                 False
# Gorontalo                                False                 False
# Sulawesi Barat                           False                 False
# Maluku                                   False                 False
# Maluku Utara                             False                 False
# Papua Barat                              False                 False
# Papua                                    False                 False
#
#                                2012 (Luas Panen)  2012 (Produksi)
# Lokasi
# Aceh                                       False            False  \
# Sumatera Utara                             False            False
# Sumatera Barat                             False            False
# Riau                                       False            False
# Jambi                                      False            False
# Sumatera Selatan                           False            False
# Bengkulu                                   False            False
# Lampung                                    False            False
# Kepulauan Bangka Belitung                  False            False
# Kepulauan Riau                             False            False
# Daerah Khusus Ibukota Jakarta              False            False
# Jawa Barat                                 False            False
# Jawa Tengah                                False            False
# Daerah Istimewa Yogyakarta                 False            False
# Jawa Timur                                 False            False
# Banten                                     False            False
# Bali                                       False            False
# Nusa Tenggara Barat                        False            False
# Nusa Tenggara Timur                        False            False
# Kalimantan Barat                           False            False
# Kalimantan Tengah                          False            False
# Kalimantan Selatan                         False            False
# Kalimantan Timur                           False            False
# Kalimantan Utara                           False            False
# Sulawesi Utara                             False            False
# Sulawesi Tengah                            False            False
# Sulawesi Selatan                           False            False
# Sulawesi Tenggara                          False            False
# Gorontalo                                  False            False
# Sulawesi Barat                             False            False
# Maluku                                     False            False
# Maluku Utara                               False            False
# Papua Barat                                False            False
# Papua                                      False            False
#
#                                2012 (Produktivitas)  2013 (Luas Panen)  ...
# Lokasi                                                                  ...
# Aceh                                          False              False  ...  \
# Sumatera Utara                                False              False  ...
# Sumatera Barat                                False              False  ...
# Riau                                          False              False  ...
# Jambi                                         False              False  ...
# Sumatera Selatan                              False              False  ...
# Bengkulu                                      False              False  ...
# Lampung                                       False              False  ...
# Kepulauan Bangka Belitung                     False              False  ...
# Kepulauan Riau                                False              False  ...
# Daerah Khusus Ibukota Jakarta                 False              False  ...
# Jawa Barat                                    False              False  ...
# Jawa Tengah                                   False              False  ...
# Daerah Istimewa Yogyakarta                    False              False  ...
# Jawa Timur                                    False              False  ...
# Banten                                        False              False  ...
# Bali                                          False              False  ...
# Nusa Tenggara Barat                           False              False  ...
# Nusa Tenggara Timur                           False              False  ...
# Kalimantan Barat                              False              False  ...
# Kalimantan Tengah                             False              False  ...
# Kalimantan Selatan                            False              False  ...
# Kalimantan Timur                              False              False  ...
# Kalimantan Utara                              False              False  ...
# Sulawesi Utara                                False              False  ...
# Sulawesi Tengah                               False              False  ...
# Sulawesi Selatan                              False              False  ...
# Sulawesi Tenggara                             False              False  ...
# Gorontalo                                     False              False  ...
# Sulawesi Barat                                False              False  ...
# Maluku                                        False              False  ...
# Maluku Utara                                  False              False  ...
# Papua Barat                                   False              False  ...
# Papua                                         False              False  ...
#
#                                2020 (Produktivitas)  2021 (Luas Panen)
# Lokasi
# Aceh                                          False              False  \
# Sumatera Utara                                False              False
# Sumatera Barat                                False              False
# Riau                                          False              False
# Jambi                                         False              False
# Sumatera Selatan                              False              False
# Bengkulu                                      False              False
# Lampung                                       False              False
# Kepulauan Bangka Belitung                     False              False
# Kepulauan Riau                                False              False
# Daerah Khusus Ibukota Jakarta                 False              False
# Jawa Barat                                    False              False
# Jawa Tengah                                   False              False
# Daerah Istimewa Yogyakarta                    False              False
# Jawa Timur                                    False              False
# Banten                                        False              False
# Bali                                          False              False
# Nusa Tenggara Barat                           False              False
# Nusa Tenggara Timur                           False              False
# Kalimantan Barat                              False              False
# Kalimantan Tengah                             False              False
# Kalimantan Selatan                            False              False
# Kalimantan Timur                              False              False
# Kalimantan Utara                              False              False
# Sulawesi Utara                                False              False
# Sulawesi Tengah                               False              False
# Sulawesi Selatan                              False              False
# Sulawesi Tenggara                             False              False
# Gorontalo                                     False              False
# Sulawesi Barat                                False              False
# Maluku                                        False              False
# Maluku Utara                                  False              False
# Papua Barat                                   False              False
# Papua                                         False              False
#
#                                2021 (Produksi)  2021 (Produktivitas)
# Lokasi
# Aceh                                     False                 False  \
# Sumatera Utara                           False                 False
# Sumatera Barat                           False                 False
# Riau                                     False                 False
# Jambi                                    False                 False
# Sumatera Selatan                         False                 False
# Bengkulu                                 False                 False
# Lampung                                  False                 False
# Kepulauan Bangka Belitung                False                 False
# Kepulauan Riau                           False                 False
# Daerah Khusus Ibukota Jakarta            False                 False
# Jawa Barat                               False                 False
# Jawa Tengah                              False                 False
# Daerah Istimewa Yogyakarta               False                 False
# Jawa Timur                               False                 False
# Banten                                   False                 False
# Bali                                     False                 False
# Nusa Tenggara Barat                      False                 False
# Nusa Tenggara Timur                      False                 False
# Kalimantan Barat                         False                 False
# Kalimantan Tengah                        False                 False
# Kalimantan Selatan                       False                 False
# Kalimantan Timur                         False                 False
# Kalimantan Utara                         False                 False
# Sulawesi Utara                           False                 False
# Sulawesi Tengah                          False                 False
# Sulawesi Selatan                         False                 False
# Sulawesi Tenggara                        False                 False
# Gorontalo                                False                 False
# Sulawesi Barat                           False                 False
# Maluku                                   False                 False
# Maluku Utara                             False                 False
# Papua Barat                              False                 False
# Papua                                    False                 False
#
#                                2022 (Luas Panen)  2022 (Produksi)
# Lokasi
# Aceh                                       False            False  \
# Sumatera Utara                             False            False
# Sumatera Barat                             False            False
# Riau                                       False            False
# Jambi                                      False            False
# Sumatera Selatan                           False            False
# Bengkulu                                   False            False
# Lampung                                    False            False
# Kepulauan Bangka Belitung                  False            False
# Kepulauan Riau                             False            False
# Daerah Khusus Ibukota Jakarta              False            False
# Jawa Barat                                 False            False
# Jawa Tengah                                False            False
# Daerah Istimewa Yogyakarta                 False            False
# Jawa Timur                                 False            False
# Banten                                     False            False
# Bali                                       False            False
# Nusa Tenggara Barat                        False            False
# Nusa Tenggara Timur                        False            False
# Kalimantan Barat                           False            False
# Kalimantan Tengah                          False            False
# Kalimantan Selatan                         False            False
# Kalimantan Timur                           False            False
# Kalimantan Utara                           False            False
# Sulawesi Utara                             False            False
# Sulawesi Tengah                            False            False
# Sulawesi Selatan                           False            False
# Sulawesi Tenggara                          False            False
# Gorontalo                                  False            False
# Sulawesi Barat                             False            False
# Maluku                                     False            False
# Maluku Utara                               False            False
# Papua Barat                                False            False
# Papua                                      False            False
#
#                                2022 (Produktivitas)  2023 (Luas Panen)
# Lokasi
# Aceh                                          False              False  \
# Sumatera Utara                                False              False
# Sumatera Barat                                False              False
# Riau                                          False              False
# Jambi                                         False              False
# Sumatera Selatan                              False              False
# Bengkulu                                      False              False
# Lampung                                       False              False
# Kepulauan Bangka Belitung                     False              False
# Kepulauan Riau                                False              False
# Daerah Khusus Ibukota Jakarta                 False              False
# Jawa Barat                                    False              False
# Jawa Tengah                                   False              False
# Daerah Istimewa Yogyakarta                    False              False
# Jawa Timur                                    False              False
# Banten                                        False              False
# Bali                                          False              False
# Nusa Tenggara Barat                           False              False
# Nusa Tenggara Timur                           False              False
# Kalimantan Barat                              False              False
# Kalimantan Tengah                             False              False
# Kalimantan Selatan                            False              False
# Kalimantan Timur                              False              False
# Kalimantan Utara                              False              False
# Sulawesi Utara                                False              False
# Sulawesi Tengah                               False              False
# Sulawesi Selatan                              False              False
# Sulawesi Tenggara                             False              False
# Gorontalo                                     False              False
# Sulawesi Barat                                False              False
# Maluku                                        False              False
# Maluku Utara                                  False              False
# Papua Barat                                   False              False
# Papua                                         False              False
#
#                                2023 (Produksi)  2023 (Produktivitas)
# Lokasi
# Aceh                                     False                 False
# Sumatera Utara                           False                 False
# Sumatera Barat                           False                 False
# Riau                                     False                 False
# Jambi                                    False                 False
# Sumatera Selatan                         False                 False
# Bengkulu                                 False                 False
# Lampung                                  False                 False
# Kepulauan Bangka Belitung                False                 False
# Kepulauan Riau                           False                 False
# Daerah Khusus Ibukota Jakarta            False                 False
# Jawa Barat                               False                 False
# Jawa Tengah                              False                 False
# Daerah Istimewa Yogyakarta               False                 False
# Jawa Timur                               False                 False
# Banten                                   False                 False
# Bali                                     False                 False
# Nusa Tenggara Barat                      False                 False
# Nusa Tenggara Timur                      False                 False
# Kalimantan Barat                         False                 False
# Kalimantan Tengah                        False                 False
# Kalimantan Selatan                       False                 False
# Kalimantan Timur                         False                 False
# Kalimantan Utara                         False                 False
# Sulawesi Utara                           False                 False
# Sulawesi Tengah                          False                 False
# Sulawesi Selatan                         False                 False
# Sulawesi Tenggara                        False                 False
# Gorontalo                                False                 False
# Sulawesi Barat                           False                 False
# Maluku                                   False                 False
# Maluku Utara                             False                 False
# Papua Barat                              False                 False
# Papua                                    False                 False
#
# [34 rows x 42 columns]
#        2010 (Luas Panen)  2010 (Produksi)  2010 (Produktivitas)
# count       3.400000e+01     3.400000e+01             34.000000  \
# mean        3.925107e+05     1.957655e+06             43.811176
# std         5.463519e+05     3.120571e+06              9.121808
# min         3.960000e+02     1.246000e+03             26.270000
# 25%         5.361275e+04     2.750645e+05             37.235000
# 50%         1.549925e+05     6.396220e+05             43.725000
# 75%         4.524880e+05     1.996558e+06             49.270000
# max         2.037657e+06     1.173707e+07             59.290000
#
#        2011 (Luas Panen)  2011 (Produksi)  2011 (Produktivitas)
# count       3.400000e+01     3.400000e+01             34.000000  \
# mean        3.901514e+05     1.933534e+06             43.910882
# std         5.265327e+05     2.952558e+06              8.708731
# min         3.990000e+02     1.259630e+03             28.490000
# 25%         5.869500e+04     2.757602e+05             37.487500
# 50%         1.550130e+05     6.180520e+05             44.850000
# 75%         4.573700e+05     2.060131e+06             49.430000
# max         1.964426e+06     1.164387e+07             59.220000
#
#        2012 (Luas Panen)  2012 (Produksi)  2012 (Produktivitas)
# count       3.400000e+01     3.400000e+01             34.000000  \
# mean        3.965806e+05     2.009055e+06             44.762941
# std         5.333024e+05     3.062643e+06              9.280906
# min         3.770000e+02     1.323300e+03             28.010000
# 25%         5.934375e+04     2.874238e+05             37.627500
# 50%         1.511405e+05     7.569395e+05             43.760000
# 75%         4.642660e+05     2.107228e+06             49.705000
# max         1.975719e+06     1.127186e+07             61.880000
#
#        2013 (Luas Panen)  ...  2020 (Produktivitas)  2021 (Luas Panen)
# count       3.400000e+01  ...             34.000000       3.400000e+01  \
# mean        4.074690e+05  ...             44.008824       3.062294e+05
# std         5.538186e+05  ...              8.716140       4.775165e+05
# min         3.790000e+02  ...             28.560000       2.701600e+02
# 25%         6.546925e+04  ...             37.862500       5.372293e+04
# 50%         1.562545e+05  ...             45.620000       1.166881e+05
# 75%         4.708082e+05  ...             49.735000       2.918468e+05
# max         2.037021e+06  ...             58.490000       1.747481e+06
#
#        2021 (Produksi)  2021 (Produktivitas)  2022 (Luas Panen)
# count     3.400000e+01             34.000000       3.400000e+01  \
# mean      1.581654e+06             45.946471       3.074235e+05
# std       2.705818e+06              8.205644       4.807524e+05
# min       8.550100e+02             30.280000       1.794800e+02
# 25%       2.303452e+05             40.222500       5.006994e+04
# 50%       4.556093e+05             47.855000       1.116239e+05
# 75%       1.557325e+06             51.745000       2.718499e+05
# max       9.789588e+06             58.830000       1.693211e+06
#
#        2022 (Produksi)  2022 (Produktivitas)  2023 (Luas Panen)
# count     3.400000e+01             34.000000       3.400000e+01  \
# mean      1.598189e+06             45.882647       3.003167e+05
# std       2.710551e+06              8.342197       4.681626e+05
# min       5.069100e+02             28.240000       1.152700e+02
# 25%       2.200243e+05             39.390000       5.018639e+04
# 50%       4.162357e+05             47.430000       1.071039e+05
# 75%       1.495329e+06             51.812500       2.973016e+05
# max       9.526516e+06             60.590000       1.698083e+06
#
#        2023 (Produksi)  2023 (Produktivitas)
# count     3.400000e+01             34.000000
# mean      1.587174e+06             46.209706
# std       2.651196e+06              8.394783
# min       3.240100e+02             28.110000
# 25%       2.112224e+05             40.980000
# 50%       5.067605e+05             47.740000
# 75%       1.524520e+06             51.872500
# max       9.710661e+06             62.070000
#
# [8 rows x 42 columns]

# %%
#Menampilkan Informasi mengenai Data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, Aceh to Papua
# Data columns (total 42 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   2010 (Luas Panen)     34 non-null     int64
#  1   2010 (Produksi)       34 non-null     float64
#  2   2010 (Produktivitas)  34 non-null     float64
#  3   2011 (Luas Panen)     34 non-null     int64
#  4   2011 (Produksi)       34 non-null     float64
#  5   2011 (Produktivitas)  34 non-null     float64
#  6   2012 (Luas Panen)     34 non-null     int64
#  7   2012 (Produksi)       34 non-null     float64
#  8   2012 (Produktivitas)  34 non-null     float64
#  9   2013 (Luas Panen)     34 non-null     int64
#  10  2013 (Produksi)       34 non-null     float64
#  11  2013 (Produktivitas)  34 non-null     float64
#  12  2014 (Luas Panen)     34 non-null     int64
#  13  2014 (Produksi)       34 non-null     int64
#  14  2014 (Produktivitas)  34 non-null     float64
#  15  2015 (Luas Panen)     34 non-null     int64
#  16  2015 (Produksi)       34 non-null     int64
#  17  2015 (Produktivitas)  34 non-null     float64
#  18  2016 (Luas Panen)     34 non-null     int64
#  19  2016 (Produksi)       34 non-null     int64
#  20  2016 (Produktivitas)  34 non-null     float64
#  21  2017 (Luas Panen)     34 non-null     float64
#  22  2017 (Produksi)       34 non-null     float64
#  23  2017 (Produktivitas)  34 non-null     float64
#  24  2018 (Luas Panen)     34 non-null     float64
#  25  2018 (Produksi)       34 non-null     float64
#  26  2018 (Produktivitas)  34 non-null     float64
#  27  2019 (Luas Panen)     34 non-null     float64
#  28  2019 (Produksi)       34 non-null     float64
#  29  2019 (Produktivitas)  34 non-null     float64
#  30  2020 (Luas Panen)     34 non-null     float64
#  31  2020 (Produksi)       34 non-null     float64
#  32  2020 (Produktivitas)  34 non-null     float64
#  33  2021 (Luas Panen)     34 non-null     float64
#  34  2021 (Produksi)       34 non-null     float64
#  35  2021 (Produktivitas)  34 non-null     float64
#  36  2022 (Luas Panen)     34 non-null     float64
#  37  2022 (Produksi)       34 non-null     float64
#  38  2022 (Produktivitas)  34 non-null     float64
#  39  2023 (Luas Panen)     34 non-null     float64
#  40  2023 (Produksi)       34 non-null     float64
#  41  2023 (Produktivitas)  34 non-null     float64
# dtypes: float64(32), int64(10)
# memory usage: 11.4+ KB

# %% [markdown]
# Tidak ada missing values pada dataset

# %%
#Standaridasi Data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df.values)

# Mengubah hasil scaled_data (array) kembali menjadi DataFrame
df_scaled = pd.DataFrame(scaled_data, columns=df.columns, index=df.index)

# Memperbarui DataFrame asli
df.update(df_scaled)

# %%
#Menentukan Jumlah Cluster Optimal
cluster_range = range(2, 10)
fpc_values = []

for c in cluster_range:
    # Fuzzy C-Means
    cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(
        scaled_data.T, c, 1.5, error=0.001, maxiter=5000, init=None
    )
    fpc_values.append(fpc)

# Plot hasil FPC untuk menentukan jumlah cluster optimal
plt.figure(figsize=(8, 5))
plt.plot(cluster_range, fpc_values, marker='o')
plt.xlabel("Number of Clusters (c)")
plt.ylabel("Fuzzy Partition Coefficient (FPC)")
plt.title("FPC vs Number of Clusters")
plt.show()

# %%
optimal_k = 2

# %%
#Melakukan Fuzzy C-Means
cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(
    scaled_data.T, optimal_k, 1.5, error=0.001, maxiter=5000, init=None
)

# Menentukan cluster untuk tiap provinsi berdasarkan keanggotaan tertinggi
cluster_membership = np.argmax(u, axis=0)
df['Cluster'] = cluster_membership

# %%
#Melakukan Visualisasi
plt.figure(figsize=(8, 6))
for j in range(optimal_k):
    plt.scatter(scaled_data[cluster_membership == j, 0], 
                scaled_data[cluster_membership == j, 1], label=f'Cluster {j+1}')

plt.xlabel('Fitur Luas Panen (Scaled)')
plt.ylabel('Fitur Produksi (Scaled)')
plt.legend()
plt.title('Clustering Fuzzy C-Means untuk Data Padi 34 Provinsi')
plt.show()

# %%
#Menampilkan Daftar Cluster
df['Cluster']
# Out:
# Lokasi
# Aceh                             0
# Sumatera Utara                   0
# Sumatera Barat                   0
# Riau                             0
# Jambi                            0
# Sumatera Selatan                 0
# Bengkulu                         0
# Lampung                          0
# Kepulauan Bangka Belitung        0
# Kepulauan Riau                   0
# Daerah Khusus Ibukota Jakarta    0
# Jawa Barat                       1
# Jawa Tengah                      1
# Daerah Istimewa Yogyakarta       0
# Jawa Timur                       1
# Banten                           0
# Bali                             0
# Nusa Tenggara Barat              0
# Nusa Tenggara Timur              0
# Kalimantan Barat                 0
# Kalimantan Tengah                0
# Kalimantan Selatan               0
# Kalimantan Timur                 0
# Kalimantan Utara                 0
# Sulawesi Utara                   0
# Sulawesi Tengah                  0
# Sulawesi Selatan                 0
# Sulawesi Tenggara                0
# Gorontalo                        0
# Sulawesi Barat                   0
# Maluku                           0
# Maluku Utara                     0
# Papua Barat                      0
# Papua                            0
# Name: Cluster, dtype: int64

# %%
#Menampilkan Distribusi C0 dan C1
cluster_distribution = df.groupby('Cluster').size()
cluster_distribution
# Out:
# Cluster
# 0    31
# 1     3
# dtype: int64

# %%
# Visualisasi distribusi tiap cluster
plt.figure(figsize=(8,6))
cluster_distribution.plot(kind='bar', color=['red', 'blue', 'orange'])
plt.title('Plot Distribusi Cluster')
plt.xlabel('Cluster')
plt.ylabel('Jumlah Provinsi')
plt.grid(True)
plt.show()

# %%
#Menampilkan Rata-rata Setiap Cluster
cluster_means = df.groupby('Cluster').mean()
cluster_means
# Out:
#          2010 (Luas Panen)  2010 (Produksi)  2010 (Produktivitas)
# Cluster
# 0                -0.280188        -0.290109             -0.149277  \
# 1                 2.895279         2.997796              1.542526
#
#          2011 (Luas Panen)  2011 (Produksi)  2011 (Produktivitas)
# Cluster
# 0                -0.276419        -0.285138             -0.138539  \
# 1                 2.856334         2.946421              1.431570
#
#          2012 (Luas Panen)  2012 (Produksi)  2012 (Produktivitas)
# Cluster
# 0                -0.274956        -0.285868             -0.154849  \
# 1                 2.841216         2.953965              1.600104
#
#          2013 (Luas Panen)  ...  2020 (Produktivitas)  2021 (Luas Panen)
# Cluster                     ...
# 0                -0.277282  ...             -0.144267          -0.283166  \
# 1                 2.865247  ...              1.490762           2.926054
#
#          2021 (Produksi)  2021 (Produktivitas)  2022 (Luas Panen)
# Cluster
# 0              -0.287724             -0.126416          -0.280743  \
# 1               2.973152              1.306297           2.901009
#
#          2022 (Produksi)  2022 (Produktivitas)  2023 (Luas Panen)
# Cluster
# 0              -0.284812             -0.122076          -0.281406  \
# 1               2.943055              1.261450           2.907864
#
#          2023 (Produksi)  2023 (Produktivitas)
# Cluster
# 0              -0.286198             -0.123140
# 1               2.957379              1.272443
#
# [2 rows x 42 columns]

# %% [markdown]
# 0 = Rendah <br> 1 = Tinggi

# %%
#Menghitung Silhouette Score
from sklearn.metrics import silhouette_score 
features = df.drop(columns=['Cluster'])  # Mengambil fitur tanpa kolom 'Cluster'
silhouette_avg = silhouette_score(features, df['Cluster'])
print(f"Silhouette Score untuk K={optimal_k}: {silhouette_avg}")
# Out:
# Silhouette Score untuk K=2: 0.6894886798059865

# %% [markdown]
# Silhouette Score untuk K=2: 0.6894886798059865 <br>
# Silhouette Score untuk K=3: 0.42647663291559773

# %%
# Import tambahan untuk Davies-Bouldin Index
from sklearn.metrics import davies_bouldin_score

# Menghitung Davies-Bouldin Index
dbi = davies_bouldin_score(features, df['Cluster'])
print(f"Davies-Bouldin Index untuk K={optimal_k}: {dbi}")
# Out:
# Davies-Bouldin Index untuk K=2: 0.3618860533098534

# %%
# Menghitung Davies-Bouldin Index untuk berbagai nilai K
dbi_values = []

for c in cluster_range:
    cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(
        scaled_data.T, c, 1.5, error=0.001, maxiter=5000, init=None
    )
    
    # Menentukan cluster untuk tiap provinsi berdasarkan keanggotaan tertinggi
    cluster_membership = np.argmax(u, axis=0)
    dbi = davies_bouldin_score(scaled_data, cluster_membership)
    dbi_values.append(dbi)

# Plot DBI untuk berbagai jumlah cluster
plt.figure(figsize=(8, 5))
plt.plot(cluster_range, dbi_values, marker='o')
plt.xlabel("Number of Clusters (c)")
plt.ylabel("Davies-Bouldin Index (DBI)")
plt.title("DBI vs Number of Clusters")
plt.show()

# Menampilkan nilai DBI untuk setiap K
for k, dbi in zip(cluster_range, dbi_values):
    print(f"DBI untuk K={k}: {dbi}")
# Out:
# DBI untuk K=2: 0.3618860533098534
# DBI untuk K=3: 0.7177186611541275
# DBI untuk K=4: 0.8677869813225214
# DBI untuk K=5: 0.7928653931729561
# DBI untuk K=6: 0.8822011017390118
# DBI untuk K=7: 0.7689532277088186
# DBI untuk K=8: 0.813988896150558
# DBI untuk K=9: 0.6908794699569478

# %%
#Melakukan Visualisasi Subplot
import seaborn as sns
import matplotlib.pyplot as plt

# Daftar tahun yang ingin ditampilkan
years = list(range(2010, 2024))  # Tahun dari 2010 hingga 2023
num_years = len(years)

# Mengatur ukuran plot dan jumlah subplot
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(20, 20))  # Sesuaikan jumlah baris dan kolom sesuai kebutuhan
axes = axes.flatten()

for i, year in enumerate(years):
    # Filter kolom untuk tahun tertentu
    data_year = df.filter(like=str(year), axis=1)
    data_year['Cluster'] = df['Cluster']
    
    # Reshape data untuk plotting
    data_year_melted = data_year.melt(id_vars='Cluster', var_name='Variable', value_name='Value')
    
    # Plot box plot pada subplot
    sns.boxplot(x='Cluster', y='Value', hue='Variable', data=data_year_melted, ax=axes[i])
    axes[i].set_title(f'Perbandingan Cluster untuk Tahun {year}')
    axes[i].set_xlabel('Cluster')
    axes[i].set_ylabel('Nilai')

    # Menyembunyikan legend di setiap subplot, kecuali yang terakhir
    if i < num_years - 1:
        axes[i].get_legend().remove()

# Mengatur layout agar lebih rapi
plt.tight_layout()
plt.show()
# Out:
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_18176\750664372.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_18176\750664372.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_18176\750664372.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_18176\750664372.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_18176\750664372.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_18176\750664372.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_18176\750664372.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_18176\750664372.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_18176\750664372.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_18176\750664372.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_18176\750664372.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_18176\750664372.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_18176\750664372.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_18176\750664372.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']

# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\python310\lib\site-packages (1.0.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\python310\lib\site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\python310\lib\site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: numpy>=1.22 in c:\python310\lib\site-packages (from geopandas) (1.24.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\python310\lib\site-packages (from geopandas) (3.7.0)
# Requirement already satisfied: packaging in c:\users\yosia amadeus\appdata\roaming\python\python310\site-packages (from geopandas) (24.1)
# Requirement already satisfied: shapely>=2.0.0 in c:\python310\lib\site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: tzdata>=2022.1 in c:\python310\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python310\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: certifi in c:\users\yosia amadeus\appdata\roaming\python\python310\site-packages (from pyogrio>=0.7.2->geopandas) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import Library
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# Muat shapefile Indonesia
gdf = gpd.read_file("gadm41_IDN_1.shp")# Mengembalikan index ke kolom biasa
df_reset = df.reset_index()  # df adalah DataFrame asli Anda yang memiliki kolom 'Lokasi' sebagai index

# Pastikan DataFrame 'df' memiliki nama provinsi yang sama dengan data shapefile
# Hanya ambil kolom Cluster dan Provinsi
data_clustering = df[['Cluster']].reset_index().rename(columns={'Lokasi': 'provinsi'})

# Agregasi data ke level provinsi
gdf_provinsi = gdf.dissolve(by='NAME_1')  # Menggabungkan data kabupaten ke provinsi
gdf_provinsi = gdf_provinsi.merge(data_clustering, left_on='NAME_1', right_on='provinsi', how='left')# Mengembalikan index ke kolom biasa
df_reset = df.reset_index()  # df adalah DataFrame asli Anda yang memiliki kolom 'Lokasi' sebagai index

# Kamus penyesuaian nama provinsi
kamus_penyesuaian = {
    "Daerah Khusus Ibukota Jakarta": "Jakarta Raya",
    "Kepulauan Bangka Belitung": "Bangka Belitung",
    "Daerah Istimewa Yogyakarta": "Yogyakarta",
}

# Terapkan kamus untuk mengganti nama provinsi di df
df_reset['Lokasi'] = df_reset['Lokasi'].replace(kamus_penyesuaian)

# Ganti 'Lokasi' menjadi 'provinsi' untuk konsistensi
data_clustering = df_reset[['Lokasi', 'Cluster']].rename(columns={'Lokasi': 'provinsi'})

# Menggabungkan data ke level provinsi
gdf_provinsi = gdf.dissolve(by='NAME_1')  # Menggabungkan data kabupaten ke provinsi
gdf_provinsi = gdf_provinsi.merge(data_clustering, left_on='NAME_1', right_on='provinsi', how='left')

# Atur warna berdasarkan cluster
color_map = {0: 'red', 1: 'blue'}
gdf_provinsi['color'] = gdf_provinsi['Cluster'].map(color_map)
gdf_provinsi['color'] = gdf_provinsi['color'].fillna('lightgrey')  # Warna abu-abu untuk provinsi tanpa data

# Visualisasikan peta dengan warna cluster
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
gdf_provinsi.plot(ax=ax, color=gdf_provinsi['color'], alpha=0.7, edgecolor='black')

# Tambahkan grid
ax.grid(True, which='both', linestyle='--', linewidth=0.5)

# Tambahkan label provinsi
for x, y, label in zip(gdf_provinsi.geometry.centroid.x, gdf_provinsi.geometry.centroid.y, gdf_provinsi['provinsi']):
    ax.text(x, y, label, fontsize=8, ha='center', va='center', color='black')

# Menambahkan legenda kustom
import matplotlib.patches as mpatches
red_patch = mpatches.Patch(color='red', label='Cluster 0 (Rendah)')
blue_patch = mpatches.Patch(color='blue', label='Cluster 1 (Tinggi)')
plt.legend(handles=[red_patch, blue_patch], loc='upper right')

# Tambahkan judul dan label
plt.title("Visualisasi Hasil Clustering Produktivitas Padi di 34 Provinsi Indonesia")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()
# Out:
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_18176\573673185.py:49: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   for x, y, label in zip(gdf_provinsi.geometry.centroid.x, gdf_provinsi.geometry.centroid.y, gdf_provinsi['provinsi']):
