# %%
#Import Library
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score 
from sklearn.preprocessing import StandardScaler

# %%
#Membaca dan Menampilkan Dataset
#Menjadikan Kolom 'Lokasi' Sebagai Index
df = pd.read_excel('AllCity&Regency 2.0.xlsx', index_col = 'Lokasi')
df
# Out:
#                  2010 (Luas Panen)  2010 (Produksi)  2010 (Produktivitas)
# Lokasi
# Simeulue                    5236.0          20976.0                 40.06  \
# Aceh Singkil                1363.0           5160.0                 37.86
# Aceh Selatan               11855.0          51464.0                 43.41
# Aceh Tenggara              21469.0          94594.0                 44.06
# Aceh Timur                 33013.0         146217.0                 44.29
# ...                            ...              ...                   ...
# Bantul                     30726.0         190356.0                 61.95
# Gunung Kidul               53803.0         259282.0                 48.19
# Sleman                     44838.0         266073.0                 59.34
# Kota Yogyakarta              215.0           1319.0                 61.35
# Kulon Progo                17476.0         106857.0                 61.14
#
#                  2011 (Luas Panen)  2011 (Produksi)  2011 (Produktivitas)
# Lokasi
# Simeulue                    5288.0          19134.0                 36.18  \
# Aceh Singkil                1580.0           4493.0                 28.44
# Aceh Selatan               12738.0          46369.0                 36.40
# Aceh Tenggara              17102.0          69554.0                 40.67
# Aceh Timur                 41795.0         193714.0                 46.35
# ...                            ...              ...                   ...
# Bantul                     30699.0         198004.0                 64.50
# Gunung Kidul               57375.0         277813.0                 48.42
# Sleman                     41080.0         232713.0                 56.65
# Kota Yogyakarta              218.0           1304.0                 59.82
# Kulon Progo                21455.0         131100.0                 62.04
#
#                  2012 (Luas Panen)  2012 (Produksi)  2012 (Produktivitas)
# Lokasi
# Simeulue                    7353.0          26005.0                 35.37  \
# Aceh Singkil                1710.0           6611.0                 38.66
# Aceh Selatan               15248.0          64309.0                 42.18
# Aceh Tenggara              13902.0          62462.0                 44.93
# Aceh Timur                 46488.0         213033.0                 45.83
# ...                            ...              ...                   ...
# Bantul                     30205.0         205355.0                 67.99
# Gunung Kidul               56416.0         291695.0                 51.70
# Sleman                     46299.0         312815.0                 67.56
# Kota Yogyakarta              169.0           1121.0                 66.33
# Kulon Progo                19823.0         135238.0                 68.22
#
#                  2013 (Luas Panen)  ...  2020 (Produktivitas)
# Lokasi                              ...
# Simeulue                    5913.0  ...                 31.38  \
# Aceh Singkil                1308.0  ...                 50.97
# Aceh Selatan               17066.0  ...                 54.00
# Aceh Tenggara              22720.0  ...                 63.72
# Aceh Timur                 43825.0  ...                 49.19
# ...                            ...  ...                   ...
# Bantul                     32692.0  ...                 56.60
# Gunung Kidul               58924.0  ...                 41.89
# Sleman                     49083.0  ...                 46.84
# Kota Yogyakarta              165.0  ...                 52.71
# Kulon Progo                18402.0  ...                 52.38
#
#                  2021 (Luas Panen)  2021 (Produksi)  2021 (Produktivitas)
# Lokasi
# Simeulue                   5586.80         16728.21                 29.94  \
# Aceh Singkil                647.32          3350.51                 51.76
# Aceh Selatan               8930.58         44839.80                 50.21
# Aceh Tenggara             10644.51         65559.88                 61.59
# Aceh Timur                27425.19        138347.01                 50.45
# ...                            ...              ...                   ...
# Bantul                    24670.88        141942.75                 57.53
# Gunung Kidul              41993.90        197399.07                 47.01
# Sleman                    24525.71        123590.16                 50.39
# Kota Yogyakarta               5.90            31.20                 52.88
# Kulon Progo               16309.77         93567.85                 57.37
#
#                  2022 (Luas Panen)  2022 (Produksi)  2022 (Produktivitas)
# Lokasi
# Simeulue                   4568.38         11648.15                 25.50  \
# Aceh Singkil                398.80          2203.58                 55.26
# Aceh Selatan               6780.36         30288.69                 44.67
# Aceh Tenggara             10572.44         69478.52                 65.72
# Aceh Timur                24556.61        130151.43                 53.00
# ...                            ...              ...                   ...
# Bantul                    24010.84        130339.44                 54.28
# Gunung Kidul              43703.94        198309.83                 45.38
# Sleman                    23796.17        116951.41                 49.15
# Kota Yogyakarta               8.26            43.09                 52.17
# Kulon Progo               19408.03        116055.76                 59.80
#
#                  2023 (Luas Panen)  2023 (Produksi)  2023 (Produktivitas)
# Lokasi
# Simeulue                   5780.84         22042.94                 39.59
# Aceh Singkil                568.49          2589.40                 51.38
# Aceh Selatan               9437.58         46345.03                 52.13
# Aceh Tenggara             10809.75         63764.22                 64.34
# Aceh Timur                20932.84        108241.39                 52.21
# ...                            ...              ...                   ...
# Bantul                    22924.01        123289.21                 53.78
# Gunung Kidul              41616.38        191255.42                 45.95
# Sleman                    22943.66        115592.50                 50.38
# Kota Yogyakarta               7.08            36.08                 50.96
# Kulon Progo               18202.53        103940.48                 59.80
#
# [516 rows x 42 columns]

# %%
#Memeriksa Missing Values
null_values = df.isnull()
print(null_values)
df.describe()
# Out:
#                  2010 (Luas Panen)  2010 (Produksi)  2010 (Produktivitas)
# Lokasi
# Simeulue                     False            False                 False  \
# Aceh Singkil                 False            False                 False
# Aceh Selatan                 False            False                 False
# Aceh Tenggara                False            False                 False
# Aceh Timur                   False            False                 False
# ...                            ...              ...                   ...
# Bantul                       False            False                 False
# Gunung Kidul                 False            False                 False
# Sleman                       False            False                 False
# Kota Yogyakarta              False            False                 False
# Kulon Progo                  False            False                 False
#
#                  2011 (Luas Panen)  2011 (Produksi)  2011 (Produktivitas)
# Lokasi
# Simeulue                     False            False                 False  \
# Aceh Singkil                 False            False                 False
# Aceh Selatan                 False            False                 False
# Aceh Tenggara                False            False                 False
# Aceh Timur                   False            False                 False
# ...                            ...              ...                   ...
# Bantul                       False            False                 False
# Gunung Kidul                 False            False                 False
# Sleman                       False            False                 False
# Kota Yogyakarta              False            False                 False
# Kulon Progo                  False            False                 False
#
#                  2012 (Luas Panen)  2012 (Produksi)  2012 (Produktivitas)
# Lokasi
# Simeulue                     False            False                 False  \
# Aceh Singkil                 False            False                 False
# Aceh Selatan                 False            False                 False
# Aceh Tenggara                False            False                 False
# Aceh Timur                   False            False                 False
# ...                            ...              ...                   ...
# Bantul                       False            False                 False
# Gunung Kidul                 False            False                 False
# Sleman                       False            False                 False
# Kota Yogyakarta              False            False                 False
# Kulon Progo                  False            False                 False
#
#                  2013 (Luas Panen)  ...  2020 (Produktivitas)
# Lokasi                              ...
# Simeulue                     False  ...                 False  \
# Aceh Singkil                 False  ...                 False
# Aceh Selatan                 False  ...                 False
# Aceh Tenggara                False  ...                 False
# Aceh Timur                   False  ...                 False
# ...                            ...  ...                   ...
# Bantul                       False  ...                 False
# Gunung Kidul                 False  ...                 False
# Sleman                       False  ...                 False
# Kota Yogyakarta              False  ...                 False
# Kulon Progo                  False  ...                 False
#
#                  2021 (Luas Panen)  2021 (Produksi)  2021 (Produktivitas)
# Lokasi
# Simeulue                     False            False                 False  \
# Aceh Singkil                 False            False                 False
# Aceh Selatan                 False            False                 False
# Aceh Tenggara                False            False                 False
# Aceh Timur                   False            False                 False
# ...                            ...              ...                   ...
# Bantul                       False            False                 False
# Gunung Kidul                 False            False                 False
# Sleman                       False            False                 False
# Kota Yogyakarta              False            False                 False
# Kulon Progo                  False            False                 False
#
#                  2022 (Luas Panen)  2022 (Produksi)  2022 (Produktivitas)
# Lokasi
# Simeulue                     False            False                 False  \
# Aceh Singkil                 False            False                 False
# Aceh Selatan                 False            False                 False
# Aceh Tenggara                False            False                 False
# Aceh Timur                   False            False                 False
# ...                            ...              ...                   ...
# Bantul                       False            False                 False
# Gunung Kidul                 False            False                 False
# Sleman                       False            False                 False
# Kota Yogyakarta              False            False                 False
# Kulon Progo                  False            False                 False
#
#                  2023 (Luas Panen)  2023 (Produksi)  2023 (Produktivitas)
# Lokasi
# Simeulue                     False            False                 False
# Aceh Singkil                 False            False                 False
# Aceh Selatan                 False            False                 False
# Aceh Tenggara                False            False                 False
# Aceh Timur                   False            False                 False
# ...                            ...              ...                   ...
# Bantul                       False            False                 False
# Gunung Kidul                 False            False                 False
# Sleman                       False            False                 False
# Kota Yogyakarta              False            False                 False
# Kulon Progo                  False            False                 False
#
# [516 rows x 42 columns]
#        2010 (Luas Panen)  2010 (Produksi)  2010 (Produktivitas)
# count         516.000000     5.160000e+02            516.000000  \
# mean        31851.368023     1.312192e+05             43.364748
# std         50580.257622     1.941110e+05             11.799278
# min             2.000000     5.300000e-01              0.000000
# 25%          2126.750000     8.215000e+03             35.182500
# 50%         13072.500000     4.371100e+04             43.770000
# 75%         41864.250000     1.778800e+05             52.240000
# max        461294.000000     1.358441e+06             69.910000
#
#        2011 (Luas Panen)  2011 (Produksi)  2011 (Produktivitas)
# count         516.000000     5.160000e+02            516.000000  \
# mean        31784.412597     1.298622e+05             43.222597
# std         51159.236270     1.889452e+05             12.268100
# min             2.000000     5.300000e-01              0.170000
# 25%          2055.250000     7.635750e+03             34.987500
# 50%         13146.000000     4.666500e+04             43.865000
# 75%         41869.500000     1.787545e+05             52.375000
# max        511044.000000     1.415050e+06             79.300000
#
#        2012 (Luas Panen)  2012 (Produksi)  2012 (Produktivitas)
# count         516.000000     5.160000e+02            516.000000  \
# mean        32478.718798     1.350135e+05             44.926163
# std         52082.782569     1.964535e+05             12.506812
# min             1.000000     5.300000e-01              0.170000
# 25%          2019.500000     7.775250e+03             36.622500
# 50%         14365.000000     5.148700e+04             45.155000
# 75%         43229.000000     1.696085e+05             53.817500
# max        481192.000000     1.376604e+06             80.250000
#
#        2013 (Luas Panen)  ...  2020 (Produktivitas)  2021 (Luas Panen)
# count         516.000000  ...             516.00000         516.000000  \
# mean        33219.278876  ...              44.30662       24043.614244
# std         52941.270162  ...              12.37910       37776.233359
# min             2.000000  ...               0.04000           0.170000
# 25%          2221.500000  ...              35.60750        1238.485000
# 50%         14872.500000  ...              45.31500        7847.685000
# 75%         43531.000000  ...              53.67250       31553.422500
# max        477489.000000  ...              75.19000      323107.610000
#
#        2021 (Produksi)  2021 (Produktivitas)  2022 (Luas Panen)
# count     5.160000e+02            516.000000         516.000000  \
# mean      1.073766e+05             46.004372       24091.222403
# std       1.779063e+05             11.423411       39005.441125
# min       5.300000e-01              0.050000           0.170000
# 25%       4.442580e+03             38.680000        1187.210000
# 50%       2.933261e+04             47.370000        7742.665000
# 75%       1.264627e+05             54.197500       31059.567500
# max       1.319624e+06             75.540000      331769.450000
#
#        2022 (Produksi)  2022 (Produktivitas)  2023 (Luas Panen)
# count     5.160000e+02            516.000000         516.000000  \
# mean      1.076140e+05             45.445174       23650.904496
# std       1.840987e+05             11.678777       37770.005115
# min       5.300000e-01              0.050000           0.110000
# 25%       4.858347e+03             38.257500         994.005000
# 50%       2.925859e+04             46.695000        7756.030000
# 75%       1.325716e+05             54.280000       31057.790000
# max       1.499996e+06             74.770000      312405.530000
#
#        2023 (Produksi)  2023 (Produktivitas)
# count     5.160000e+02            516.000000
# mean      1.069378e+05             46.056802
# std       1.774520e+05             11.436602
# min       4.300000e-01              0.100000
# 25%       4.344100e+03             39.035000
# 50%       3.095659e+04             47.220000
# 75%       1.337371e+05             54.337500
# max       1.424303e+06             71.660000
#
# [8 rows x 42 columns]

# %%
#Menampilkan Informasi mengenai Data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 516 entries, Simeulue to Kulon Progo
# Data columns (total 42 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   2010 (Luas Panen)     516 non-null    float64
#  1   2010 (Produksi)       516 non-null    float64
#  2   2010 (Produktivitas)  516 non-null    float64
#  3   2011 (Luas Panen)     516 non-null    float64
#  4   2011 (Produksi)       516 non-null    float64
#  5   2011 (Produktivitas)  516 non-null    float64
#  6   2012 (Luas Panen)     516 non-null    float64
#  7   2012 (Produksi)       516 non-null    float64
#  8   2012 (Produktivitas)  516 non-null    float64
#  9   2013 (Luas Panen)     516 non-null    float64
#  10  2013 (Produksi)       516 non-null    float64
#  11  2013 (Produktivitas)  516 non-null    float64
#  12  2014 (Luas Panen)     516 non-null    float64
#  13  2014 (Produksi)       516 non-null    float64
#  14  2014 (Produktivitas)  516 non-null    float64
#  15  2015 (Luas Panen)     516 non-null    float64
#  16  2015 (Produksi)       516 non-null    float64
#  17  2015 (Produktivitas)  516 non-null    float64
#  18  2016 (Luas Panen)     516 non-null    float64
#  19  2016 (Produksi)       516 non-null    float64
#  20  2016 (Produktivitas)  516 non-null    float64
#  21  2017 (Luas Panen)     516 non-null    float64
#  22  2017 (Produksi)       516 non-null    float64
#  23  2017 (Produktivitas)  516 non-null    float64
#  24  2018 (Luas Panen)     516 non-null    float64
#  25  2018 (Produksi)       516 non-null    float64
#  26  2018 (Produktivitas)  516 non-null    float64
#  27  2019 (Luas Panen)     516 non-null    float64
#  28  2019 (Produksi)       516 non-null    float64
#  29  2019 (Produktivitas)  516 non-null    float64
#  30  2020 (Luas Panen)     516 non-null    float64
#  31  2020 (Produksi)       516 non-null    float64
#  32  2020 (Produktivitas)  516 non-null    float64
#  33  2021 (Luas Panen)     516 non-null    float64
#  34  2021 (Produksi)       516 non-null    float64
#  35  2021 (Produktivitas)  516 non-null    float64
#  36  2022 (Luas Panen)     516 non-null    float64
#  37  2022 (Produksi)       516 non-null    float64
#  38  2022 (Produktivitas)  516 non-null    float64
#  39  2023 (Luas Panen)     516 non-null    float64
#  40  2023 (Produksi)       516 non-null    float64
#  41  2023 (Produktivitas)  516 non-null    float64
# dtypes: float64(42)
# memory usage: 173.3+ KB

# %% [markdown]
# Tidak ada missing values pada dataset

# %%
#Standaridasi Data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df.values)

# Mengubah hasil scaled_data (array) kembali menjadi DataFrame
df_scaled = pd.DataFrame(scaled_data, columns=df.columns, index=df.index)

# Memperbarui DataFrame asli
df.update(df_scaled)

# %%
#Menentukan Nilai k Terbaik Menggunakan Elbow Method
inertia = []
K = range(1, 11)

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df)
    inertia.append(kmeans.inertia_)

#Melakukan Visualisasi Elbow Method
plt.figure(figsize=(8, 5))
plt.plot(K, inertia, 'bo-', markersize=8)
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method For Optimal k')
plt.grid(True)
plt.show()

# %%
#Melakukan K-Means Clustering
kmeans = KMeans(init="k-means++", n_clusters=2, n_init=500, random_state=42)
df['Cluster'] = kmeans.fit_predict(df)
df
# Out:
#                  2010 (Luas Panen)  2010 (Produksi)  2010 (Produktivitas)
# Lokasi
# Simeulue                 -0.526711        -0.568490             -0.280352  \
# Aceh Singkil             -0.603357        -0.650049             -0.466985
# Aceh Selatan             -0.395723        -0.411273              0.003839
# Aceh Tenggara            -0.205464        -0.188865              0.058980
# Aceh Timur                0.022988         0.077339              0.078492
# ...                            ...              ...                   ...
# Bantul                   -0.022271         0.304950              1.576646
# Gunung Kidul              0.434417         0.660380              0.409342
# Sleman                    0.257002         0.695399              1.355232
# Kota Yogyakarta          -0.626076        -0.669855              1.525746
# Kulon Progo              -0.284485        -0.125629              1.507931
#
#                  2011 (Luas Panen)  2011 (Produksi)  2011 (Produktivitas)
# Lokasi
# Simeulue                 -0.518423        -0.586602             -0.574615  \
# Aceh Singkil             -0.590973        -0.664166             -1.206132
# Aceh Selatan             -0.372658        -0.442320             -0.556665
# Aceh Tenggara            -0.287273        -0.319493             -0.208270
# Aceh Timur                0.195865         0.338266              0.255169
# ...                            ...              ...                   ...
# Bantul                   -0.021237         0.360993              1.736051
# Gunung Kidul              0.500700         0.783795              0.424063
# Sleman                    0.181875         0.544870              1.095559
# Kota Yogyakarta          -0.617622        -0.681060              1.354204
# Kulon Progo              -0.202103         0.006557              1.535337
#
#                  2012 (Luas Panen)  2012 (Produksi)  2012 (Produktivitas)
# Lokasi
# Simeulue                 -0.482887        -0.555420             -0.764818  \
# Aceh Singkil             -0.591339        -0.654237             -0.501506
# Aceh Selatan             -0.331154        -0.360254             -0.219786
# Aceh Tenggara            -0.357023        -0.369665              0.000307
# Aceh Timur                0.269242         0.397525              0.072338
# ...                            ...              ...                   ...
# Bantul                   -0.043698         0.358404              1.845892
# Gunung Kidul              0.460047         0.798324              0.542137
# Sleman                    0.265610         0.905935              1.811477
# Kota Yogyakarta          -0.620955        -0.682209              1.713035
# Kulon Progo              -0.243228         0.001144              1.864299
#
#                  2013 (Luas Panen)  ...  2021 (Luas Panen)  2021 (Produksi)
# Lokasi                              ...
# Simeulue                 -0.516285  ...          -0.489057        -0.510023  \
# Aceh Singkil             -0.603352  ...          -0.619940        -0.585291
# Aceh Selatan             -0.305413  ...          -0.400455        -0.351856
# Aceh Tenggara            -0.198512  ...          -0.355041        -0.235277
# Aceh Timur                0.200524  ...           0.089603         0.174252
# ...                            ...  ...                ...              ...
# Bantul                   -0.009969  ...           0.016621         0.194483
# Gunung Kidul              0.486004  ...           0.475635         0.506502
# Sleman                    0.299938  ...           0.012774         0.091224
# Kota Yogyakarta          -0.624963  ...          -0.636936        -0.603967
# Kulon Progo              -0.280153  ...          -0.204926        -0.077693
#
#                  2021 (Produktivitas)  2022 (Luas Panen)  2022 (Produksi)
# Lokasi
# Simeulue                    -1.407632          -0.501002        -0.521780  \
# Aceh Singkil                 0.504334          -0.608003        -0.573131
# Aceh Selatan                 0.368516          -0.444237        -0.420428
# Aceh Tenggara                1.365683          -0.346923        -0.207348
# Aceh Timur                   0.389546           0.011943         0.122539
# ...                               ...                ...              ...
# Bantul                       1.009927          -0.002063         0.123562
# Gunung Kidul                 0.088118           0.503308         0.493126
# Sleman                       0.384288          -0.007572         0.050769
# Kota Yogyakarta              0.602473          -0.618025        -0.584878
# Kulon Progo                  0.995907          -0.120182         0.045899
#
#                  2022 (Produktivitas)  2023 (Luas Panen)  2023 (Produksi)
# Lokasi
# Simeulue                    -1.709471          -0.473588        -0.478875  \
# Aceh Singkil                 0.841214          -0.611724        -0.588608
# Aceh Selatan                -0.066439          -0.376678        -0.341792
# Aceh Tenggara                1.737725          -0.340313        -0.243533
# Aceh Timur                   0.647513          -0.072033         0.007353
# ...                               ...                ...              ...
# Bantul                       0.757220          -0.019264         0.092235
# Gunung Kidul                -0.005586           0.476116         0.475618
# Sleman                       0.317535          -0.018743         0.048819
# Kota Yogyakarta              0.576375          -0.626602        -0.603011
# Kulon Progo                  1.230330          -0.144391        -0.016907
#
#                  2023 (Produktivitas)  Cluster
# Lokasi
# Simeulue                    -0.565997        0
# Aceh Singkil                 0.465904        0
# Aceh Selatan                 0.531547        0
# Aceh Tenggara                1.600208        0
# Aceh Timur                   0.538549        0
# ...                               ...      ...
# Bantul                       0.675961        0
# Gunung Kidul                -0.009348        0
# Sleman                       0.378381        0
# Kota Yogyakarta              0.429145        0
# Kulon Progo                  1.202852        0
#
# [516 rows x 43 columns]

# %%
#Menampilkan Distribusi C0, C1, dan C2
cluster_distribution = df.groupby('Cluster').size()
cluster_distribution
# Out:
# Cluster
# 0    433
# 1     83
# dtype: int64

# %%
# Visualisasi distribusi tiap cluster
plt.figure(figsize=(8,6))
cluster_distribution.plot(kind='bar', color=['red', 'blue', 'orange'])
plt.title('Plot Distribusi Cluster')
plt.xlabel('Cluster')
plt.ylabel('Jumlah Provinsi')
plt.grid(True)
plt.show()

# %%
#Menampilkan Rata-rata Setiap Cluster
cluster_means = df.groupby('Cluster').mean()
cluster_means
# Out:
#          2010 (Luas Panen)  2010 (Produksi)  2010 (Produktivitas)
# Cluster
# 0                -0.301487        -0.346230             -0.178120  \
# 1                 1.572816         1.806235              0.929226
#
#          2011 (Luas Panen)  2011 (Produksi)  2011 (Produktivitas)
# Cluster
# 0                -0.296809        -0.341262              -0.16115  \
# 1                 1.548414         1.780317               0.84070
#
#          2012 (Luas Panen)  2012 (Produksi)  2012 (Produktivitas)
# Cluster
# 0                -0.298975        -0.342214             -0.175879  \
# 1                 1.559711         1.785286              0.917536
#
#          2013 (Luas Panen)  ...  2020 (Produktivitas)  2021 (Luas Panen)
# Cluster                     ...
# 0                -0.303754  ...             -0.167202          -0.336475  \
# 1                 1.584645  ...              0.872272           1.755345
#
#          2021 (Produksi)  2021 (Produktivitas)  2022 (Luas Panen)
# Cluster
# 0              -0.336264             -0.160538          -0.332268  \
# 1               1.754245              0.837508           1.733400
#
#          2022 (Produksi)  2022 (Produktivitas)  2023 (Luas Panen)
# Cluster
# 0              -0.334714             -0.167725          -0.332946  \
# 1               1.746158              0.875002           1.736934
#
#          2023 (Produksi)  2023 (Produktivitas)
# Cluster
# 0              -0.338355             -0.166623
# 1               1.765151              0.869250
#
# [2 rows x 42 columns]

# %% [markdown]
# 0 = Rendah, 1 = Tinggi

# %%
df['Cluster']
# Out:
# Lokasi
# Simeulue           0
# Aceh Singkil       0
# Aceh Selatan       0
# Aceh Tenggara      0
# Aceh Timur         0
#                   ..
# Bantul             0
# Gunung Kidul       0
# Sleman             0
# Kota Yogyakarta    0
# Kulon Progo        0
# Name: Cluster, Length: 516, dtype: int32

# %%
optimal_k = 2

# %%
# 5. Menghitung Silhouette Score
from sklearn.metrics import silhouette_score
features = df.drop(columns=['Cluster'])  # Mengambil fitur tanpa kolom 'Cluster'
silhouette_avg = silhouette_score(features, df['Cluster'])
print(f"Silhouette Score untuk K={optimal_k}: {silhouette_avg}")
# Out:
# Silhouette Score untuk K=2: 0.5207500260953024

# %% [markdown]
# Silhouette Score untuk K=2: 0.5207935729775067 <br> Silhouette Score untuk K=3: 0.3212521977127988 <br> Silhouette Score untuk K=2: 0.29416113998052246

# %%
# Import tambahan untuk Davies-Bouldin Index
from sklearn.metrics import davies_bouldin_score

# Menghitung Davies-Bouldin Index
dbi = davies_bouldin_score(features, df['Cluster'])
print(f"Davies-Bouldin Index untuk K={optimal_k}: {dbi}")
# Out:
# Davies-Bouldin Index untuk K=2: 0.877684942359106

# %%
# Menghitung Davies-Bouldin Index untuk berbagai jumlah K
cluster_range = range(2, 11)  # Mencoba nilai K dari 2 hingga 10
dbi_values = []  # Menyimpan nilai DBI untuk setiap K

# Loop untuk menghitung DBI untuk setiap jumlah cluster (K)
for k in cluster_range:
    # Melakukan K-Means clustering
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(scaled_data)  # Data yang telah distandarisasi
    
    # Menyimpan label cluster untuk setiap data point
    cluster_labels = kmeans.labels_
    
    # Menghitung Davies-Bouldin Index
    dbi = davies_bouldin_score(scaled_data, cluster_labels)
    dbi_values.append(dbi)

# Plot DBI untuk berbagai jumlah cluster
plt.figure(figsize=(8, 5))
plt.plot(cluster_range, dbi_values, marker='o')
plt.xlabel("Number of Clusters (K)")
plt.ylabel("Davies-Bouldin Index (DBI)")
plt.title("DBI vs Number of Clusters (K-Means)")
plt.xticks(cluster_range)
plt.show()

# Menampilkan nilai DBI untuk setiap K
for k, dbi in zip(cluster_range, dbi_values):
    print(f"DBI untuk K={k}: {dbi}")
# Out:
# DBI untuk K=2: 0.867403978011647
# DBI untuk K=3: 1.0244407426634339
# DBI untuk K=4: 0.9440364760060558
# DBI untuk K=5: 0.9770488739826565
# DBI untuk K=6: 0.9814081218211586
# DBI untuk K=7: 1.035686767157852
# DBI untuk K=8: 1.0733823395479893
# DBI untuk K=9: 1.1867557303841485
# DBI untuk K=10: 1.1074669016228167

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Daftar tahun yang ingin ditampilkan
years = list(range(2010, 2024))  # Tahun dari 2010 hingga 2023
num_years = len(years)

# Mengatur ukuran plot dan jumlah subplot
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(20, 20))  # Sesuaikan jumlah baris dan kolom sesuai kebutuhan
axes = axes.flatten()

for i, year in enumerate(years):
    # Filter kolom untuk tahun tertentu
    data_year = df.filter(like=str(year), axis=1)
    data_year['Cluster'] = df['Cluster']
    
    # Reshape data untuk plotting
    data_year_melted = data_year.melt(id_vars='Cluster', var_name='Variable', value_name='Value')
    
    # Plot box plot pada subplot
    sns.boxplot(x='Cluster', y='Value', hue='Variable', data=data_year_melted, ax=axes[i])
    axes[i].set_title(f'Perbandingan Cluster untuk Tahun {year}')
    axes[i].set_xlabel('Cluster')
    axes[i].set_ylabel('Nilai')

    # Menyembunyikan legend di setiap subplot, kecuali yang terakhir
    if i < num_years - 1:
        axes[i].get_legend().remove()

# Mengatur layout agar lebih rapi
plt.tight_layout()
plt.show()
# Out:
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_13852\384623709.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_13852\384623709.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_13852\384623709.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_13852\384623709.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_13852\384623709.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_13852\384623709.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_13852\384623709.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_13852\384623709.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_13852\384623709.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_13852\384623709.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_13852\384623709.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_13852\384623709.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_13852\384623709.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']
# C:\Users\YOSIA AMADEUS\AppData\Local\Temp\ipykernel_13852\384623709.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_year['Cluster'] = df['Cluster']

# %%
# Import Library
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# Memuat shapefile Indonesia
gdf = gpd.read_file("gadm41_IDN_2.shp")

print(gdf)
# Out:
#           GID_2 GID_0    COUNTRY     GID_1      NAME_1 NL_NAME_1
# 0     IDN.1.2_1   IDN  Indonesia   IDN.1_1        Aceh        NA  \
# 1     IDN.1.1_1   IDN  Indonesia   IDN.1_1        Aceh        NA
# 2     IDN.1.3_1   IDN  Indonesia   IDN.1_1        Aceh        NA
# 3     IDN.1.4_1   IDN  Indonesia   IDN.1_1        Aceh        NA
# 4     IDN.1.5_1   IDN  Indonesia   IDN.1_1        Aceh        NA
# ..          ...   ...        ...       ...         ...       ...
# 497  IDN.33.1_1   IDN  Indonesia  IDN.33_1  Yogyakarta        NA
# 498  IDN.33.2_1   IDN  Indonesia  IDN.33_1  Yogyakarta        NA
# 499  IDN.33.3_1   IDN  Indonesia  IDN.33_1  Yogyakarta        NA
# 500  IDN.33.4_1   IDN  Indonesia  IDN.33_1  Yogyakarta        NA
# 501  IDN.33.5_1   IDN  Indonesia  IDN.33_1  Yogyakarta        NA
#
#               NAME_2 VARNAME_2 NL_NAME_2     TYPE_2 ENGTYPE_2  CC_2    HASC_2
# 0         Aceh Barat        NA        NA  Kabupaten   Regency  1107  ID.AC.AB  \
# 1    Aceh Barat Daya        NA        NA  Kabupaten   Regency  1112  ID.AC.AD
# 2         Aceh Besar        NA        NA  Kabupaten   Regency  1108  ID.AC.AR
# 3          Aceh Jaya        NA        NA  Kabupaten   Regency  1116  ID.AC.AJ
# 4       Aceh Selatan        NA        NA  Kabupaten   Regency  1103  ID.AC.AS
# ..               ...       ...       ...        ...       ...   ...       ...
# 497           Bantul        NA        NA  Kabupaten   Regency  3402  ID.YO.BA
# 498     Gunung Kidul        NA        NA  Kabupaten   Regency  3403  ID.YO.GK
# 499  Kota Yogyakarta        NA        NA       Kota      City  3471  ID.YO.YO
# 500      Kulon Progo        NA        NA  Kabupaten   Regency  3401  ID.YO.KP
# 501           Sleman        NA        NA  Kabupaten   Regency  3404  ID.YO.SL
#
#                                               geometry
# 0    POLYGON ((96.06915 4.19539, 96.06725 4.19651, ...
# 1    MULTIPOLYGON (((96.94196 3.57464, 96.9411 3.57...
# 2    MULTIPOLYGON (((95.78426 5.24092, 95.78445 5.2...
# 3    MULTIPOLYGON (((95.87673 4.36754, 95.87687 4.3...
# 4    MULTIPOLYGON (((97.74693 2.44002, 97.74638 2.4...
# ..                                                 ...
# 497  POLYGON ((110.32938 -8.00756, 110.32954 -8.008...
# 498  MULTIPOLYGON (((110.60487 -8.1475, 110.60499 -...
# 499  POLYGON ((110.39351 -7.82868, 110.3933 -7.8288...
# 500  POLYGON ((110.14531 -7.95117, 110.14469 -7.951...
# 501  POLYGON ((110.29926 -7.82715, 110.29819 -7.827...
#
# [502 rows x 14 columns]

# %%
# Ekstrak nama provinsi dari gdf dan df
provinsi_gdf = set(gdf['NAME_2'].unique())
provinsi_df = set(df.index.unique())

# Cari nama provinsi yang ada di gdf tetapi tidak ada di df
provinsi_tidak_ada_di_df = provinsi_gdf - provinsi_df

# Tampilkan hasil
print("Kota di gdf yang tidak ada di df:")
print(provinsi_tidak_ada_di_df)
# Out:
# Kota di gdf yang tidak ada di df:
# {'Lake Toba', 'Danau', 'Kota Pontianak', 'Danau Limboto', 'Waduk Cirata', 'Waduk Kedungombo'}

# %%
# Import Library
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# Memuat shapefile Indonesia
gdf = gpd.read_file("gadm41_IDN_2.shp")

# Mengembalikan index ke kolom biasa
df_reset = df.reset_index()  # df adalah DataFrame asli Anda yang memiliki kolom 'Lokasi' sebagai index

# Kamus penyesuaian nama provinsi jika diperlukan
kamus_penyesuaian = {
    "Daerah Khusus Ibukota Jakarta": "Jakarta Raya",
    "Kepulauan Bangka Belitung": "Bangka Belitung",
    "Daerah Istimewa Yogyakarta": "Yogyakarta",
}

# Terapkan kamus untuk mengganti nama provinsi di df
df_reset['Lokasi'] = df_reset['Lokasi'].replace(kamus_penyesuaian)

# Ganti 'Lokasi' menjadi 'provinsi' untuk konsistensi
data_clustering = df_reset[['Lokasi', 'Cluster']].rename(columns={'Lokasi': 'provinsi'})

# Menggabungkan data ke level provinsi
gdf_provinsi = gdf.dissolve(by='NAME_2')  # Menggabungkan data kabupaten ke provinsi
gdf_provinsi = gdf_provinsi.merge(data_clustering, left_on='NAME_2', right_on='provinsi', how='left')

# Atur warna berdasarkan cluster
color_map = {0: 'red', 1: 'blue'}
gdf_provinsi['color'] = gdf_provinsi['Cluster'].map(color_map)
gdf_provinsi['color'] = gdf_provinsi['color'].fillna('lightgrey')  # Warna abu-abu untuk kabupaten/kota tanpa data

# Visualisasikan peta dengan warna cluster
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
gdf_provinsi.plot(ax=ax, color=gdf_provinsi['color'], alpha=0.7, edgecolor='black')

# Tambahkan grid
ax.grid(True, which='both', linestyle='--', linewidth=0.5)

# Menambahkan legenda kustom
import matplotlib.patches as mpatches
red_patch = mpatches.Patch(color='red', label='Cluster 0 (Rendah)')
blue_patch = mpatches.Patch(color='blue', label='Cluster 1 (Tinggi)')
plt.legend(handles=[red_patch, blue_patch], loc='upper right')

# Tambahkan judul dan label
plt.title("Visualisasi Hasil Clustering Kabupaten/Kota di Indonesia")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()
